# %%
# import the pandas package
# note that this was specified as a project
# dependency in the pyproject.toml file
import pandas
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\saket\research-paper-template-saket\files\data-science\video-games\explore-videogame-dataset.ipynb Cell 1 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/research-paper-template-saket/files/data-science/video-games/explore-videogame-dataset.ipynb#ch0000000?line=0'>1</a> # import the pandas package
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/research-paper-template-saket/files/data-science/video-games/explore-videogame-dataset.ipynb#ch0000000?line=1'>2</a> # note that this was specified as a project
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/research-paper-template-saket/files/data-science/video-games/explore-videogame-dataset.ipynb#ch0000000?line=2'>3</a> # dependency in the pyproject.toml file
# ...

# %%
# WORKS ON: Local Jupyter Lab Server or Local or Remote Jupyter Lite Server
#
# DOES NOT WORK ON: Google Colab
#
# Read in the validation data set by using the local file.
#
# Note that this will not work in Google Colab unless
# you also upload this file to your Colab account.
validation_data = pandas.read_csv('GamingStudy_data.csv')

# display the entire data frame of a total of 200 rows
validation_data

# modifying the Jupyter Notebook, which will appear in the GitHub repository after a git commit!
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 1           2  42052.00680     1     2     2     2     0     1     0
# 2           3  42052.03860     0     2     2     0     0     3     1
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13459   14246  42057.75678     1     0     0     1     0     1     1
# 13460   14247  42057.81185     3     3     3     3     2     3     3
# 13461   14248  42058.16964     0     0     0     0     0     0     0
# 13462   14249  42058.24420     3     2     1     3     0     1     3
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...  Birthplace    Residence  Reference  \
# ...

# %%
# WORKS ON: Local Jupyter Lab Server or Google Colab
#
# DOES NOT WORK ON: Local or Remote Jupyter Lite Server
#
# Read in the validation data set by using the raw
# file that is stored in the GitHub repository.
#
# Note that this will not work correctly if the file called
# validation.csv is moved to a different location in the 
# GitHub repository, thus causing the file's URL to change
validation_data = pandas.read_csv('https://raw.githubusercontent.com/hurb404/research-paper-template-saket/master/files/data-science/video-games/GamingStudy_data.csv')

# display the entire data frame of a total of 200 rows
validation_data

# %%
df = validation_data
df.hist(column=["GAD1"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\saket\research-paper-template-saket\files\data-science\video-games\explore-videogame-dataset.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/saket/research-paper-template-saket/files/data-science/video-games/explore-videogame-dataset.ipynb#ch0000003?line=0'>1</a> df = validation_data
#       <a href='vscode-notebook-cell:/c%3A/Users/saket/research-paper-template-saket/files/data-science/video-games/explore-videogame-dataset.ipynb#ch0000003?line=1'>2</a> df.hist(column=["GAD1", "Hours"])
#
# NameError: name 'validation_data' is not defined

# %%
df = validation_data
df.hist(column=["SWL1"])

# %%
df = validation_data
df.hist(column=["SPIN1"])

# %%
df = validation_data
df.hist(column=["Hours"])
